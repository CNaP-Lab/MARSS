# %%
# https://test.pypi.org/project/MARSS120824/0.0.1/
# %pip install -i https://test.pypi.org/simple/ MARSS120824==0.0.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://test.pypi.org/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import MARSS120824 as MARSS
from inspect import getmembers, isfunction

# MARSS.MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
timeseriesFile = "/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii"
MB = 6
workingDir = "/mnt/new_jxvs2_02/AshleyWorkspace/50017_PhilTesting"

MARSS.MARSS_main(timeseriesFile, MB, workingDir,"/mnt/new_jxvs2_02/AshleyWorkspace/50017_PhilTesting/rp_50017_fMRI_Resting_1_AP.txt")
# Out:
# User provided motion parameters. Skipping motion parameter estimation...
# Generating pre-MARSS Motion Parameters and Slice Correlations...
# /home/aszhao/.local/lib/python3.11/site-packages/MARSS120824/MARSS.py:174: RuntimeWarning: divide by zero encountered in divide
#   cZ = 0.5 * np.log((1 + c) / (1 - c))
# Performing MARSS Procedure...
# Generating post-MARSS Motion Parameters and Slice Correlations...
