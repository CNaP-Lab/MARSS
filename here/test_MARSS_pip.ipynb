# %%
# %pip install -i https://test.pypi.org/simple/ MARSS==0.0.0
# %pip install -i https://test.pypi.org/simple/ MARSS112524==0.0.0
# %pip install -i https://test.pypi.org/simple/ MARSS308112524==0.0.1
# %pip install nibabel
# %pip install pandas
# %pip install -i https://test.pypi.org/simple/ MARSS315112524==0.0.1
# %pip install -i https://test.pypi.org/simple/  --extra-index-url https://pypi.org/simple MARSS316120224==0.0.1

# %pip install -i https://test.pypi.org/simple/ MARSS357120224==0.0.1

# import MARSS112524
# import MARSS
# import marss

# matrix = text_to_matrix('/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/2875_3T_RS_fMRI_1/rp_2875_3T_RS_fMRI_1.nii.par')
# # print(matrix)

# # print(MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/"))
# # MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
# [postMARSS_fname, postMARSS_avgSlcArt_fname] = MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/")
# # MARSS_avgMBcorr(postMARSS_fname,6)
# MARSS_mbCorrPlot(postMARSS_fname, matrix, 6)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://test.pypi.org/simple/
# Collecting MARSS357120224==0.0.1
#   Downloading https://test-files.pythonhosted.org/packages/d4/63/60e3d9f0f67108fadf1339334d64153f4b5772b9b930a2874df60ca815e6/MARSS357120224-0.0.1-py3-none-any.whl.metadata (741 bytes)
# Requirement already satisfied: numpy in /usr/local/lib64/python3.11/site-packages (from MARSS357120224==0.0.1) (1.26.4)
# Requirement already satisfied: nibabel in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (5.3.2)
# Requirement already satisfied: pandas in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (2.2.3)
# Requirement already satisfied: matplotlib in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (3.9.3)
# Requirement already satisfied: scipy in /usr/local/lib64/python3.11/site-packages (from MARSS357120224==0.0.1) (1.12.0)
# Requirement already satisfied: networkx in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (3.4.2)
# Requirement already satisfied: traits in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (6.4.3)
# Requirement already satisfied: python-dateutil in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (2.9.0.post0)
# Requirement already satisfied: traitsui in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (8.0.0)
# Requirement already satisfied: nipype[all] in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (1.9.1)
# Requirement already satisfied: seaborn in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS357120224==0.0.1) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (24.1)
# Requirement already satisfied: pillow>=8 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS357120224==0.0.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from python-dateutil->MARSS357120224==0.0.1) (1.16.0)
# Requirement already satisfied: importlib-resources>=5.12 in /home/aszhao/.local/lib/python3.11/site-packages (from nibabel->MARSS357120224==0.0.1) (6.4.5)
# Requirement already satisfied: typing-extensions>=4.6 in /home/aszhao/.local/lib/python3.11/site-packages (from nibabel->MARSS357120224==0.0.1) (4.12.2)
# Requirement already satisfied: click>=6.6.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (8.1.7)
# Requirement already satisfied: prov>=1.5.2 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (2.0.1)
# Requirement already satisfied: pydot>=1.2.3 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (3.0.3)
# Requirement already satisfied: rdflib>=5.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (6.3.2)
# Requirement already satisfied: simplejson>=3.8.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (3.19.3)
# Requirement already satisfied: filelock>=3.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (3.16.1)
# Requirement already satisfied: acres in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.1.0)
# Requirement already satisfied: etelemetry>=0.3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.3.1)
# Requirement already satisfied: looseversion!=1.2 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (1.3.0)
# Requirement already satisfied: puremagic in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (1.28)
# Requirement already satisfied: pytest-cov>=2.11 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (6.0.0)
# Requirement already satisfied: GitPython in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (3.1.43)
# Requirement already satisfied: pytest-env in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (1.1.5)
# Requirement already satisfied: paramiko in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (3.5.0)
# Requirement already satisfied: datalad in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (1.1.4)
# Requirement already satisfied: coverage>=5.2.1 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (7.6.8)
# Requirement already satisfied: pytest>=6 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (8.3.4)
# Requirement already satisfied: sphinx>=7 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (8.1.3)
# Requirement already satisfied: nitime in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.11)
# Requirement already satisfied: xvfbwrapper in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.2.9)
# Requirement already satisfied: ipython in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (8.29.0)
# Requirement already satisfied: sphinx-argparse in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.5.2)
# Requirement already satisfied: black in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (24.10.0)
# Requirement already satisfied: pytest-doctestplus in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (1.3.0)
# Requirement already satisfied: nbsphinx in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.9.5)
# Requirement already satisfied: nipy in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.6.1)
# Requirement already satisfied: nilearn in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.11.0)
# Requirement already satisfied: psutil>=5.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (6.1.0)
# Requirement already satisfied: duecredit in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.10.2)
# Requirement already satisfied: pytest-timeout>=1.4 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (2.3.1)
# Requirement already satisfied: dipy in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (1.9.0)
# Requirement already satisfied: pytest-xdist>=2.5 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (3.6.1)
# Requirement already satisfied: pybids>=0.7.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.18.0)
# Requirement already satisfied: fuzzywuzzy in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.18.0)
# Requirement already satisfied: sphinxcontrib-apidoc in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS357120224==0.0.1) (0.5.0)
# Requirement already satisfied: pytz>=2020.1 in /home/aszhao/.local/lib/python3.11/site-packages (from pandas->MARSS357120224==0.0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/aszhao/.local/lib/python3.11/site-packages (from pandas->MARSS357120224==0.0.1) (2024.2)
# Requirement already satisfied: pyface>=8.0 in /home/aszhao/.local/lib/python3.11/site-packages (from traitsui->MARSS357120224==0.0.1) (8.0.0)
# Requirement already satisfied: requests in /home/aszhao/.local/lib/python3.11/site-packages (from etelemetry>=0.3.1->nipype[all]->MARSS357120224==0.0.1) (2.32.3)
# Requirement already satisfied: ci-info>=0.2 in /home/aszhao/.local/lib/python3.11/site-packages (from etelemetry>=0.3.1->nipype[all]->MARSS357120224==0.0.1) (0.3.0)
# Requirement already satisfied: lxml>=3.3.5 in /home/aszhao/.local/lib/python3.11/site-packages (from prov>=1.5.2->nipype[all]->MARSS357120224==0.0.1) (5.3.0)
# Requirement already satisfied: formulaic<0.6,>=0.2.4 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (0.5.2)
# Requirement already satisfied: sqlalchemy>=1.3.16 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (2.0.36)
# Requirement already satisfied: bids-validator>=1.14.7 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.5 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (0.5.13)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (0.2.5)
# Requirement already satisfied: iniconfig in /home/aszhao/.local/lib/python3.11/site-packages (from pytest>=6->nipype[all]->MARSS357120224==0.0.1) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from pytest>=6->nipype[all]->MARSS357120224==0.0.1) (1.5.0)
# Requirement already satisfied: execnet>=2.1 in /home/aszhao/.local/lib/python3.11/site-packages (from pytest-xdist>=2.5->nipype[all]->MARSS357120224==0.0.1) (2.1.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/aszhao/.local/lib/python3.11/site-packages (from rdflib>=5.0.0->nipype[all]->MARSS357120224==0.0.1) (0.6.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (3.1.4)
# Requirement already satisfied: Pygments>=2.17 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.18.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (1.4.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/aszhao/.local/lib/python3.11/site-packages (from black->nipype[all]->MARSS357120224==0.0.1) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/aszhao/.local/lib/python3.11/site-packages (from black->nipype[all]->MARSS357120224==0.0.1) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/aszhao/.local/lib/python3.11/site-packages (from black->nipype[all]->MARSS357120224==0.0.1) (4.3.6)
# Requirement already satisfied: chardet>=3.0.4 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (5.2.0)
# Requirement already satisfied: distro in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (1.9.0)
# Requirement already satisfied: iso8601 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (2.1.0)
# Requirement already satisfied: humanize in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (4.11.0)
# Requirement already satisfied: fasteners>=0.14 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (0.19)
# Requirement already satisfied: patool>=1.7 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (3.1.0)
# Requirement already satisfied: tqdm>=4.32.0 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (4.67.1)
# Requirement already satisfied: annexremote in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (1.6.6)
# Requirement already satisfied: boto3 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (1.35.72)
# Requirement already satisfied: keyring!=23.9.0,>=20.0 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (25.5.0)
# Requirement already satisfied: keyrings.alt in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (5.0.2)
# Requirement already satisfied: msgpack in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (1.1.0)
# Requirement already satisfied: python-gitlab in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS357120224==0.0.1) (5.1.0)
# Requirement already satisfied: h5py>=3.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from dipy->nipype[all]->MARSS357120224==0.0.1) (3.12.1)
# Requirement already satisfied: trx-python>=0.2.9 in /home/aszhao/.local/lib/python3.11/site-packages (from dipy->nipype[all]->MARSS357120224==0.0.1) (0.3)
# Requirement already satisfied: citeproc-py>=0.4 in /home/aszhao/.local/lib/python3.11/site-packages (from duecredit->nipype[all]->MARSS357120224==0.0.1) (0.6.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from GitPython->nipype[all]->MARSS357120224==0.0.1) (4.0.11)
# Requirement already satisfied: decorator in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (3.0.48)
# Requirement already satisfied: stack-data in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS357120224==0.0.1) (4.9.0)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /home/aszhao/.local/lib/python3.11/site-packages (from nbsphinx->nipype[all]->MARSS357120224==0.0.1) (7.16.4)
# Requirement already satisfied: nbformat in /home/aszhao/.local/lib/python3.11/site-packages (from nbsphinx->nipype[all]->MARSS357120224==0.0.1) (5.10.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nilearn->nipype[all]->MARSS357120224==0.0.1) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nilearn->nipype[all]->MARSS357120224==0.0.1) (1.5.2)
# Requirement already satisfied: sympy>=1.9 in /home/aszhao/.local/lib/python3.11/site-packages (from nipy->nipype[all]->MARSS357120224==0.0.1) (1.13.3)
# Requirement already satisfied: transforms3d in /home/aszhao/.local/lib/python3.11/site-packages (from nipy->nipype[all]->MARSS357120224==0.0.1) (0.4.2)
# Requirement already satisfied: bcrypt>=3.2 in /home/aszhao/.local/lib/python3.11/site-packages (from paramiko->nipype[all]->MARSS357120224==0.0.1) (4.2.1)
# Requirement already satisfied: cryptography>=3.3 in /home/aszhao/.local/lib/python3.11/site-packages (from paramiko->nipype[all]->MARSS357120224==0.0.1) (44.0.0)
# Requirement already satisfied: pynacl>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from paramiko->nipype[all]->MARSS357120224==0.0.1) (1.5.0)
# Requirement already satisfied: pbr in /home/aszhao/.local/lib/python3.11/site-packages (from sphinxcontrib-apidoc->nipype[all]->MARSS357120224==0.0.1) (6.1.0)
# Requirement already satisfied: bidsschematools>=0.10 in /home/aszhao/.local/lib/python3.11/site-packages (from bids-validator>=1.14.7->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (0.11.3.post3)
# Requirement already satisfied: cffi>=1.12 in /home/aszhao/.local/lib/python3.11/site-packages (from cryptography>=3.3->paramiko->nipype[all]->MARSS357120224==0.0.1) (1.17.1)
# Requirement already satisfied: astor>=0.8 in /home/aszhao/.local/lib/python3.11/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython->nipype[all]->MARSS357120224==0.0.1) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/aszhao/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython->nipype[all]->MARSS357120224==0.0.1) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from Jinja2>=3.1->sphinx>=7->nipype[all]->MARSS357120224==0.0.1) (3.0.2)
# Requirement already satisfied: jaraco.classes in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (3.4.0)
# Requirement already satisfied: jaraco.functools in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (4.1.0)
# Requirement already satisfied: jaraco.context in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (6.0.1)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (8.5.0)
# Requirement already satisfied: SecretStorage>=3.2 in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (0.8.0)
# Requirement already satisfied: beautifulsoup4 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (6.2.0)
# Requirement already satisfied: defusedxml in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/aszhao/.local/lib/python3.11/site-packages (from nbformat->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/aszhao/.local/lib/python3.11/site-packages (from nbformat->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (4.23.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/aszhao/.local/lib/python3.11/site-packages (from num2words>=0.5.5->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (0.6.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/aszhao/.local/lib/python3.11/site-packages (from pexpect>4.3->ipython->nipype[all]->MARSS357120224==0.0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /home/aszhao/.local/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->nipype[all]->MARSS357120224==0.0.1) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS357120224==0.0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS357120224==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS357120224==0.0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS357120224==0.0.1) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from scikit-learn>=1.4.0->nilearn->nipype[all]->MARSS357120224==0.0.1) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/aszhao/.local/lib/python3.11/site-packages (from sqlalchemy>=1.3.16->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (3.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from sympy>=1.9->nipy->nipype[all]->MARSS357120224==0.0.1) (1.3.0)
# Requirement already satisfied: setuptools-scm in /home/aszhao/.local/lib/python3.11/site-packages (from trx-python>=0.2.9->dipy->nipype[all]->MARSS357120224==0.0.1) (8.1.0)
# Requirement already satisfied: deepdiff in /home/aszhao/.local/lib/python3.11/site-packages (from trx-python>=0.2.9->dipy->nipype[all]->MARSS357120224==0.0.1) (8.0.1)
# Requirement already satisfied: fsspec!=2024.3.1,>=2022.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from universal-pathlib>=0.2.2->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (2024.10.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.72 in /home/aszhao/.local/lib/python3.11/site-packages (from boto3->datalad->nipype[all]->MARSS357120224==0.0.1) (1.35.72)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/aszhao/.local/lib/python3.11/site-packages (from boto3->datalad->nipype[all]->MARSS357120224==0.0.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/aszhao/.local/lib/python3.11/site-packages (from boto3->datalad->nipype[all]->MARSS357120224==0.0.1) (0.10.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from python-gitlab->datalad->nipype[all]->MARSS357120224==0.0.1) (1.0.0)
# Requirement already satisfied: executing>=1.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from stack-data->ipython->nipype[all]->MARSS357120224==0.0.1) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from stack-data->ipython->nipype[all]->MARSS357120224==0.0.1) (2.4.1)
# Requirement already satisfied: pure-eval in /home/aszhao/.local/lib/python3.11/site-packages (from stack-data->ipython->nipype[all]->MARSS357120224==0.0.1) (0.2.3)
# Requirement already satisfied: pyyaml in /home/aszhao/.local/lib/python3.11/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids>=0.7.0->nipype[all]->MARSS357120224==0.0.1) (6.0.2)
# Requirement already satisfied: webencodings in /home/aszhao/.local/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (0.5.1)
# Requirement already satisfied: pycparser in /home/aszhao/.local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko->nipype[all]->MARSS357120224==0.0.1) (2.22)
# Requirement already satisfied: zipp>=3.20 in /home/aszhao/.local/lib/python3.11/site-packages (from importlib-metadata>=4.11.4->keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (0.22.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/aszhao/.local/lib/python3.11/site-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (8.6.3)
# Requirement already satisfied: soupsieve>1.2 in /home/aszhao/.local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (2.6)
# Requirement already satisfied: orderly-set==5.2.2 in /home/aszhao/.local/lib/python3.11/site-packages (from deepdiff->trx-python>=0.2.9->dipy->nipype[all]->MARSS357120224==0.0.1) (5.2.2)
# Requirement already satisfied: more-itertools in /home/aszhao/.local/lib/python3.11/site-packages (from jaraco.classes->keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (10.5.0)
# Requirement already satisfied: backports.tarfile in /home/aszhao/.local/lib/python3.11/site-packages (from jaraco.context->keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS357120224==0.0.1) (1.2.0)
# Requirement already satisfied: setuptools in /home/aszhao/.local/lib/python3.11/site-packages (from setuptools-scm->trx-python>=0.2.9->dipy->nipype[all]->MARSS357120224==0.0.1) (40.8.0)
# Requirement already satisfied: pyzmq>=23.0 in /home/aszhao/.local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /home/aszhao/.local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS357120224==0.0.1) (6.4.1)
# Downloading https://test-files.pythonhosted.org/packages/d4/63/60e3d9f0f67108fadf1339334d64153f4b5772b9b930a2874df60ca815e6/MARSS357120224-0.0.1-py3-none-any.whl (6.3 kB)
# Installing collected packages: MARSS357120224
# Successfully installed MARSS357120224-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -i https://test.pypi.org/simple/ MARSS148120424==0.0.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://test.pypi.org/simple/
# Collecting MARSS148120424==0.0.1
#   Downloading https://test-files.pythonhosted.org/packages/8a/83/a2e52e758f87d34978165c04dba51db1d399f3ad89699c46a247100553d1/MARSS148120424-0.0.1-py3-none-any.whl.metadata (741 bytes)
# Requirement already satisfied: numpy in /usr/local/lib64/python3.11/site-packages (from MARSS148120424==0.0.1) (1.26.4)
# Requirement already satisfied: nibabel in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (5.3.2)
# Requirement already satisfied: pandas in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (2.2.3)
# Requirement already satisfied: matplotlib in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (3.9.3)
# Requirement already satisfied: scipy in /usr/local/lib64/python3.11/site-packages (from MARSS148120424==0.0.1) (1.12.0)
# Requirement already satisfied: networkx in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (3.4.2)
# Requirement already satisfied: traits in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (6.4.3)
# Requirement already satisfied: python-dateutil in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (2.9.0.post0)
# Requirement already satisfied: traitsui in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (8.0.0)
# Requirement already satisfied: nipype[all] in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (1.9.1)
# Requirement already satisfied: seaborn in /home/aszhao/.local/lib/python3.11/site-packages (from MARSS148120424==0.0.1) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (24.1)
# Requirement already satisfied: pillow>=8 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib->MARSS148120424==0.0.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from python-dateutil->MARSS148120424==0.0.1) (1.16.0)
# Requirement already satisfied: importlib-resources>=5.12 in /home/aszhao/.local/lib/python3.11/site-packages (from nibabel->MARSS148120424==0.0.1) (6.4.5)
# Requirement already satisfied: typing-extensions>=4.6 in /home/aszhao/.local/lib/python3.11/site-packages (from nibabel->MARSS148120424==0.0.1) (4.12.2)
# Requirement already satisfied: click>=6.6.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (8.1.7)
# Requirement already satisfied: prov>=1.5.2 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (2.0.1)
# Requirement already satisfied: pydot>=1.2.3 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (3.0.3)
# Requirement already satisfied: rdflib>=5.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (6.3.2)
# Requirement already satisfied: simplejson>=3.8.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (3.19.3)
# Requirement already satisfied: filelock>=3.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (3.16.1)
# Requirement already satisfied: acres in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.1.0)
# Requirement already satisfied: etelemetry>=0.3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.3.1)
# Requirement already satisfied: looseversion!=1.2 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (1.3.0)
# Requirement already satisfied: puremagic in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (1.28)
# Requirement already satisfied: pytest-cov>=2.11 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (6.0.0)
# Requirement already satisfied: GitPython in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (3.1.43)
# Requirement already satisfied: pytest-env in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (1.1.5)
# Requirement already satisfied: paramiko in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (3.5.0)
# Requirement already satisfied: datalad in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (1.1.4)
# Requirement already satisfied: coverage>=5.2.1 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (7.6.8)
# Requirement already satisfied: pytest>=6 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (8.3.4)
# Requirement already satisfied: sphinx>=7 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (8.1.3)
# Requirement already satisfied: nitime in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.11)
# Requirement already satisfied: xvfbwrapper in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.2.9)
# Requirement already satisfied: ipython in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (8.29.0)
# Requirement already satisfied: sphinx-argparse in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.5.2)
# Requirement already satisfied: black in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (24.10.0)
# Requirement already satisfied: pytest-doctestplus in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (1.3.0)
# Requirement already satisfied: nbsphinx in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.9.5)
# Requirement already satisfied: nipy in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.6.1)
# Requirement already satisfied: nilearn in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.11.0)
# Requirement already satisfied: psutil>=5.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (6.1.0)
# Requirement already satisfied: duecredit in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.10.2)
# Requirement already satisfied: pytest-timeout>=1.4 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (2.3.1)
# Requirement already satisfied: dipy in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (1.9.0)
# Requirement already satisfied: pytest-xdist>=2.5 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (3.6.1)
# Requirement already satisfied: pybids>=0.7.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.18.0)
# Requirement already satisfied: fuzzywuzzy in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.18.0)
# Requirement already satisfied: sphinxcontrib-apidoc in /home/aszhao/.local/lib/python3.11/site-packages (from nipype[all]->MARSS148120424==0.0.1) (0.5.0)
# Requirement already satisfied: pytz>=2020.1 in /home/aszhao/.local/lib/python3.11/site-packages (from pandas->MARSS148120424==0.0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/aszhao/.local/lib/python3.11/site-packages (from pandas->MARSS148120424==0.0.1) (2024.2)
# Requirement already satisfied: pyface>=8.0 in /home/aszhao/.local/lib/python3.11/site-packages (from traitsui->MARSS148120424==0.0.1) (8.0.0)
# Requirement already satisfied: requests in /home/aszhao/.local/lib/python3.11/site-packages (from etelemetry>=0.3.1->nipype[all]->MARSS148120424==0.0.1) (2.32.3)
# Requirement already satisfied: ci-info>=0.2 in /home/aszhao/.local/lib/python3.11/site-packages (from etelemetry>=0.3.1->nipype[all]->MARSS148120424==0.0.1) (0.3.0)
# Requirement already satisfied: lxml>=3.3.5 in /home/aszhao/.local/lib/python3.11/site-packages (from prov>=1.5.2->nipype[all]->MARSS148120424==0.0.1) (5.3.0)
# Requirement already satisfied: formulaic<0.6,>=0.2.4 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (0.5.2)
# Requirement already satisfied: sqlalchemy>=1.3.16 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (2.0.36)
# Requirement already satisfied: bids-validator>=1.14.7 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.5 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (0.5.13)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /home/aszhao/.local/lib/python3.11/site-packages (from pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (0.2.5)
# Requirement already satisfied: iniconfig in /home/aszhao/.local/lib/python3.11/site-packages (from pytest>=6->nipype[all]->MARSS148120424==0.0.1) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from pytest>=6->nipype[all]->MARSS148120424==0.0.1) (1.5.0)
# Requirement already satisfied: execnet>=2.1 in /home/aszhao/.local/lib/python3.11/site-packages (from pytest-xdist>=2.5->nipype[all]->MARSS148120424==0.0.1) (2.1.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/aszhao/.local/lib/python3.11/site-packages (from rdflib>=5.0.0->nipype[all]->MARSS148120424==0.0.1) (0.6.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (3.1.4)
# Requirement already satisfied: Pygments>=2.17 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.18.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /home/aszhao/.local/lib/python3.11/site-packages (from sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (1.4.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/aszhao/.local/lib/python3.11/site-packages (from black->nipype[all]->MARSS148120424==0.0.1) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/aszhao/.local/lib/python3.11/site-packages (from black->nipype[all]->MARSS148120424==0.0.1) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/aszhao/.local/lib/python3.11/site-packages (from black->nipype[all]->MARSS148120424==0.0.1) (4.3.6)
# Requirement already satisfied: chardet>=3.0.4 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (5.2.0)
# Requirement already satisfied: distro in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (1.9.0)
# Requirement already satisfied: iso8601 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (2.1.0)
# Requirement already satisfied: humanize in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (4.11.0)
# Requirement already satisfied: fasteners>=0.14 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (0.19)
# Requirement already satisfied: patool>=1.7 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (3.1.0)
# Requirement already satisfied: tqdm>=4.32.0 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (4.67.1)
# Requirement already satisfied: annexremote in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (1.6.6)
# Requirement already satisfied: boto3 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (1.35.72)
# Requirement already satisfied: keyring!=23.9.0,>=20.0 in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (25.5.0)
# Requirement already satisfied: keyrings.alt in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (5.0.2)
# Requirement already satisfied: msgpack in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (1.1.0)
# Requirement already satisfied: python-gitlab in /home/aszhao/.local/lib/python3.11/site-packages (from datalad->nipype[all]->MARSS148120424==0.0.1) (5.1.0)
# Requirement already satisfied: h5py>=3.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from dipy->nipype[all]->MARSS148120424==0.0.1) (3.12.1)
# Requirement already satisfied: trx-python>=0.2.9 in /home/aszhao/.local/lib/python3.11/site-packages (from dipy->nipype[all]->MARSS148120424==0.0.1) (0.3)
# Requirement already satisfied: citeproc-py>=0.4 in /home/aszhao/.local/lib/python3.11/site-packages (from duecredit->nipype[all]->MARSS148120424==0.0.1) (0.6.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from GitPython->nipype[all]->MARSS148120424==0.0.1) (4.0.11)
# Requirement already satisfied: decorator in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (3.0.48)
# Requirement already satisfied: stack-data in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/aszhao/.local/lib/python3.11/site-packages (from ipython->nipype[all]->MARSS148120424==0.0.1) (4.9.0)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /home/aszhao/.local/lib/python3.11/site-packages (from nbsphinx->nipype[all]->MARSS148120424==0.0.1) (7.16.4)
# Requirement already satisfied: nbformat in /home/aszhao/.local/lib/python3.11/site-packages (from nbsphinx->nipype[all]->MARSS148120424==0.0.1) (5.10.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nilearn->nipype[all]->MARSS148120424==0.0.1) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nilearn->nipype[all]->MARSS148120424==0.0.1) (1.5.2)
# Requirement already satisfied: sympy>=1.9 in /home/aszhao/.local/lib/python3.11/site-packages (from nipy->nipype[all]->MARSS148120424==0.0.1) (1.13.3)
# Requirement already satisfied: transforms3d in /home/aszhao/.local/lib/python3.11/site-packages (from nipy->nipype[all]->MARSS148120424==0.0.1) (0.4.2)
# Requirement already satisfied: bcrypt>=3.2 in /home/aszhao/.local/lib/python3.11/site-packages (from paramiko->nipype[all]->MARSS148120424==0.0.1) (4.2.1)
# Requirement already satisfied: cryptography>=3.3 in /home/aszhao/.local/lib/python3.11/site-packages (from paramiko->nipype[all]->MARSS148120424==0.0.1) (44.0.0)
# Requirement already satisfied: pynacl>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from paramiko->nipype[all]->MARSS148120424==0.0.1) (1.5.0)
# Requirement already satisfied: pbr in /home/aszhao/.local/lib/python3.11/site-packages (from sphinxcontrib-apidoc->nipype[all]->MARSS148120424==0.0.1) (6.1.0)
# Requirement already satisfied: bidsschematools>=0.10 in /home/aszhao/.local/lib/python3.11/site-packages (from bids-validator>=1.14.7->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (0.11.3.post3)
# Requirement already satisfied: cffi>=1.12 in /home/aszhao/.local/lib/python3.11/site-packages (from cryptography>=3.3->paramiko->nipype[all]->MARSS148120424==0.0.1) (1.17.1)
# Requirement already satisfied: astor>=0.8 in /home/aszhao/.local/lib/python3.11/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/aszhao/.local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython->nipype[all]->MARSS148120424==0.0.1) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/aszhao/.local/lib/python3.11/site-packages (from jedi>=0.16->ipython->nipype[all]->MARSS148120424==0.0.1) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from Jinja2>=3.1->sphinx>=7->nipype[all]->MARSS148120424==0.0.1) (3.0.2)
# Requirement already satisfied: jaraco.classes in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (3.4.0)
# Requirement already satisfied: jaraco.functools in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (4.1.0)
# Requirement already satisfied: jaraco.context in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (6.0.1)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (8.5.0)
# Requirement already satisfied: SecretStorage>=3.2 in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /home/aszhao/.local/lib/python3.11/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (0.8.0)
# Requirement already satisfied: beautifulsoup4 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (6.2.0)
# Requirement already satisfied: defusedxml in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (0.10.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/aszhao/.local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/aszhao/.local/lib/python3.11/site-packages (from nbformat->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/aszhao/.local/lib/python3.11/site-packages (from nbformat->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (4.23.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/aszhao/.local/lib/python3.11/site-packages (from num2words>=0.5.5->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (0.6.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/aszhao/.local/lib/python3.11/site-packages (from pexpect>4.3->ipython->nipype[all]->MARSS148120424==0.0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /home/aszhao/.local/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->nipype[all]->MARSS148120424==0.0.1) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS148120424==0.0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS148120424==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS148120424==0.0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aszhao/.local/lib/python3.11/site-packages (from requests->etelemetry>=0.3.1->nipype[all]->MARSS148120424==0.0.1) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from scikit-learn>=1.4.0->nilearn->nipype[all]->MARSS148120424==0.0.1) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/aszhao/.local/lib/python3.11/site-packages (from sqlalchemy>=1.3.16->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (3.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from sympy>=1.9->nipy->nipype[all]->MARSS148120424==0.0.1) (1.3.0)
# Requirement already satisfied: setuptools-scm in /home/aszhao/.local/lib/python3.11/site-packages (from trx-python>=0.2.9->dipy->nipype[all]->MARSS148120424==0.0.1) (8.1.0)
# Requirement already satisfied: deepdiff in /home/aszhao/.local/lib/python3.11/site-packages (from trx-python>=0.2.9->dipy->nipype[all]->MARSS148120424==0.0.1) (8.0.1)
# Requirement already satisfied: fsspec!=2024.3.1,>=2022.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from universal-pathlib>=0.2.2->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (2024.10.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.72 in /home/aszhao/.local/lib/python3.11/site-packages (from boto3->datalad->nipype[all]->MARSS148120424==0.0.1) (1.35.72)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/aszhao/.local/lib/python3.11/site-packages (from boto3->datalad->nipype[all]->MARSS148120424==0.0.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/aszhao/.local/lib/python3.11/site-packages (from boto3->datalad->nipype[all]->MARSS148120424==0.0.1) (0.10.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/aszhao/.local/lib/python3.11/site-packages (from python-gitlab->datalad->nipype[all]->MARSS148120424==0.0.1) (1.0.0)
# Requirement already satisfied: executing>=1.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from stack-data->ipython->nipype[all]->MARSS148120424==0.0.1) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/aszhao/.local/lib/python3.11/site-packages (from stack-data->ipython->nipype[all]->MARSS148120424==0.0.1) (2.4.1)
# Requirement already satisfied: pure-eval in /home/aszhao/.local/lib/python3.11/site-packages (from stack-data->ipython->nipype[all]->MARSS148120424==0.0.1) (0.2.3)
# Requirement already satisfied: pyyaml in /home/aszhao/.local/lib/python3.11/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids>=0.7.0->nipype[all]->MARSS148120424==0.0.1) (6.0.2)
# Requirement already satisfied: webencodings in /home/aszhao/.local/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (0.5.1)
# Requirement already satisfied: pycparser in /home/aszhao/.local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko->nipype[all]->MARSS148120424==0.0.1) (2.22)
# Requirement already satisfied: zipp>=3.20 in /home/aszhao/.local/lib/python3.11/site-packages (from importlib-metadata>=4.11.4->keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/aszhao/.local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (0.22.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/aszhao/.local/lib/python3.11/site-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (8.6.3)
# Requirement already satisfied: soupsieve>1.2 in /home/aszhao/.local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (2.6)
# Requirement already satisfied: orderly-set==5.2.2 in /home/aszhao/.local/lib/python3.11/site-packages (from deepdiff->trx-python>=0.2.9->dipy->nipype[all]->MARSS148120424==0.0.1) (5.2.2)
# Requirement already satisfied: more-itertools in /home/aszhao/.local/lib/python3.11/site-packages (from jaraco.classes->keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (10.5.0)
# Requirement already satisfied: backports.tarfile in /home/aszhao/.local/lib/python3.11/site-packages (from jaraco.context->keyring!=23.9.0,>=20.0->datalad->nipype[all]->MARSS148120424==0.0.1) (1.2.0)
# Requirement already satisfied: setuptools in /home/aszhao/.local/lib/python3.11/site-packages (from setuptools-scm->trx-python>=0.2.9->dipy->nipype[all]->MARSS148120424==0.0.1) (40.8.0)
# Requirement already satisfied: pyzmq>=23.0 in /home/aszhao/.local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /home/aszhao/.local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]->MARSS148120424==0.0.1) (6.4.1)
# Downloading https://test-files.pythonhosted.org/packages/8a/83/a2e52e758f87d34978165c04dba51db1d399f3ad89699c46a247100553d1/MARSS148120424-0.0.1-py3-none-any.whl (6.3 kB)
# Installing collected packages: MARSS148120424
# Successfully installed MARSS148120424-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import MARSS120424 as MARSS
from inspect import getmembers, isfunction

MARSS.MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
# Out:
# Generating pre-MARSS Motion Parameters...
# /mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.txt

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.5/164.5 kB 7.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib64/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aszhao/.local/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/aszhao/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 54.8 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 32.6 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 104.5 MB/s eta 0:00:0000:01
# Downloading kiwisolver-1.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.0 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 87.3 MB/s eta 0:00:00:00:01
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.0 kiwisolver-1.4.7 matplotlib-3.9.3 pillow-11.0.0 pyparsing-3.2.0
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
