# %%
#MARSS (python)

# %%
# !pip install nibabel
# !pip install shutil
# !pip install pandas
# !pip install matplotlib
# !pip install scipy
# nipype dependencies
# !pip install networkx
# !pip install numpy
# !pip install traits
# !pip install python-dateutil
# !pip install Sphinx
# !pip install traitsui
# !pip install nipype[all]
# !pip install seaborn
# Out:
# heloo
# Requirement already satisfied: nibabel in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (5.2.1)
# Requirement already satisfied: numpy>=1.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nibabel) (24.1)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
# ERROR: No matching distribution found for shutil
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: packaging>=20.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: pillow>=8 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: numpy>=1.23 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from scipy) (2.0.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: networkx in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (3.2.1)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (2.0.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: traits in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (6.3.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: python-dateutil in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from python-dateutil) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: Sphinx in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (7.4.7)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.1.0)
# Requirement already satisfied: Pygments>=2.17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.18.0)
# Requirement already satisfied: Jinja2>=3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (3.1.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.0.0)
# Requirement already satisfied: babel>=2.13 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.16.0)
# Requirement already satisfied: alabaster~=0.7.14 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (0.7.16)
# Requirement already satisfied: requests>=2.30.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.32.3)
# Requirement already satisfied: docutils<0.22,>=0.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (0.21.2)
# Requirement already satisfied: imagesize>=1.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (1.4.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.2.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.0.0)
# Requirement already satisfied: packaging>=23.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (24.1)
# Requirement already satisfied: importlib-metadata>=6.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (8.5.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (1.0.1)
# Requirement already satisfied: tomli>=2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.0.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Sphinx) (2.0.0)
# Requirement already satisfied: zipp>=3.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from importlib-metadata>=6.0->Sphinx) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Jinja2>=3.1->Sphinx) (2.1.5)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests>=2.30.0->Sphinx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests>=2.30.0->Sphinx) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests>=2.30.0->Sphinx) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests>=2.30.0->Sphinx) (3.3.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: traitsui in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (8.0.0)
# Requirement already satisfied: traits>=6.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from traitsui) (6.3.2)
# Requirement already satisfied: pyface>=8.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from traitsui) (8.0.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pyface>=8.0->traitsui) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from importlib-metadata>=3.6->pyface>=8.0->traitsui) (3.20.2)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: nipype[all] in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (1.8.6)
# Requirement already satisfied: scipy>=0.14 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (1.13.1)
# Requirement already satisfied: simplejson>=3.8.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.19.3)
# Requirement already satisfied: nibabel>=2.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (5.2.1)
# Requirement already satisfied: numpy>=1.17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (2.0.2)
# Requirement already satisfied: click>=6.6.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (8.1.7)
# Requirement already satisfied: networkx>=2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.2.1)
# Requirement already satisfied: pydot>=1.2.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (2.9.0.post0)
# Requirement already satisfied: packaging in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (24.1)
# Requirement already satisfied: rdflib>=5.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (6.3.2)
# Requirement already satisfied: prov>=1.5.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (2.0.1)
# Requirement already satisfied: etelemetry>=0.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.3.1)
# Requirement already satisfied: looseversion in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (1.3.0)
# Requirement already satisfied: filelock>=3.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.16.1)
# Requirement already satisfied: traits!=5.0,<6.4,>=4.6 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (6.3.2)
# Requirement already satisfied: pytest-env in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (1.1.5)
# Requirement already satisfied: coverage<5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (4.5.4)
# Requirement already satisfied: pytest-timeout in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (2.3.1)
# Requirement already satisfied: matplotlib in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.9.2)
# Requirement already satisfied: GitPython in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.1.43)
# Requirement already satisfied: codecov in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (2.1.13)
# Requirement already satisfied: pytest in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (8.3.3)
# Requirement already satisfied: ipython in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (8.18.1)
# Requirement already satisfied: nbsphinx in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.9.5)
# Requirement already satisfied: sphinx in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (7.4.7)
# Requirement already satisfied: fuzzywuzzy in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.18.0)
# Requirement already satisfied: paramiko in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (3.5.0)
# Requirement already satisfied: datalad in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (1.1.3)
# Requirement already satisfied: nipy in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.6.0)
# Requirement already satisfied: nilearn in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.10.4)
# Requirement already satisfied: nitime in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.11)
# Requirement already satisfied: duecredit in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.10.2)
# Requirement already satisfied: pytest-cov in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (2.10.1)
# Requirement already satisfied: sphinx-argparse in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.4.0)
# Requirement already satisfied: sphinxcontrib-apidoc in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.5.0)
# Requirement already satisfied: pybids>=0.7.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.17.2)
# Requirement already satisfied: xvfbwrapper in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (0.2.9)
# Requirement already satisfied: psutil>=5.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (6.0.0)
# Requirement already satisfied: pytest-doctestplus in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (1.2.1)
# Requirement already satisfied: black in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (24.8.0)
# Requirement already satisfied: dipy in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipype[all]) (1.9.0)
# Requirement already satisfied: ci-info>=0.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from etelemetry>=0.2.0->nipype[all]) (0.3.0)
# Requirement already satisfied: requests in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from etelemetry>=0.2.0->nipype[all]) (2.32.3)
# Requirement already satisfied: lxml>=3.3.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from prov>=1.5.2->nipype[all]) (5.3.0)
# Requirement already satisfied: num2words>=0.5.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pybids>=0.7.0->nipype[all]) (0.5.13)
# Requirement already satisfied: pandas>=0.25.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pybids>=0.7.0->nipype[all]) (2.2.3)
# Requirement already satisfied: formulaic<0.6,>=0.2.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pybids>=0.7.0->nipype[all]) (0.5.2)
# Requirement already satisfied: bids-validator>=1.11 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pybids>=0.7.0->nipype[all]) (1.14.7.post0)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pybids>=0.7.0->nipype[all]) (0.2.5)
# Requirement already satisfied: sqlalchemy>=1.3.16 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pybids>=0.7.0->nipype[all]) (2.0.35)
# Requirement already satisfied: bidsschematools>=0.10 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (0.11.3)
# Requirement already satisfied: jsonschema in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from bidsschematools>=0.10->bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (4.23.0)
# Requirement already satisfied: pyyaml in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from bidsschematools>=0.10->bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]) (4.12.2)
# Requirement already satisfied: astor>=0.8 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]) (0.8.1)
# Requirement already satisfied: wrapt>=1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]) (1.16.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.7.0->nipype[all]) (1.3.0)
# Requirement already satisfied: docopt>=0.6.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from num2words>=0.5.5->pybids>=0.7.0->nipype[all]) (0.6.2)
# Requirement already satisfied: pytz>=2020.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas>=0.25.2->pybids>=0.7.0->nipype[all]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas>=0.25.2->pybids>=0.7.0->nipype[all]) (2024.2)
# Requirement already satisfied: pyparsing>=3.0.9 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pydot>=1.2.3->nipype[all]) (3.1.4)
# Requirement already satisfied: six>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from python-dateutil>=2.2->nipype[all]) (1.16.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from rdflib>=5.0.0->nipype[all]) (0.6.1)
# Requirement already satisfied: imagesize>=1.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (1.4.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (3.1.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.0.0)
# Requirement already satisfied: importlib-metadata>=6.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (8.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.0.0)
# Requirement already satisfied: babel>=2.13 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.16.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.2.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (0.21.2)
# Requirement already satisfied: alabaster~=0.7.14 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (0.7.16)
# Requirement already satisfied: sphinxcontrib-jsmath in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.0.0)
# Requirement already satisfied: tomli>=2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.0.1)
# Requirement already satisfied: Pygments>=2.17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.18.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinx->nipype[all]) (2.1.0)
# Requirement already satisfied: zipp>=3.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from importlib-metadata>=6.0->sphinx->nipype[all]) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from Jinja2>=3.1->sphinx->nipype[all]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests->etelemetry>=0.2.0->nipype[all]) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests->etelemetry>=0.2.0->nipype[all]) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests->etelemetry>=0.2.0->nipype[all]) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from requests->etelemetry>=0.2.0->nipype[all]) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sqlalchemy>=1.3.16->pybids>=0.7.0->nipype[all]) (3.1.1)
# Requirement already satisfied: fsspec!=2024.3.1,>=2022.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from universal-pathlib>=0.2.2->pybids>=0.7.0->nipype[all]) (2024.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from black->nipype[all]) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from black->nipype[all]) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from black->nipype[all]) (4.3.6)
# Requirement already satisfied: fasteners>=0.14 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (0.19)
# Requirement already satisfied: humanize in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (4.10.0)
# Requirement already satisfied: keyring!=23.9.0,>=20.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (25.4.1)
# Requirement already satisfied: msgpack in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (1.1.0)
# Requirement already satisfied: iso8601 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (2.1.0)
# Requirement already satisfied: annexremote in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (1.6.6)
# Requirement already satisfied: patool>=1.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (1.15.0)
# Requirement already satisfied: chardet>=3.0.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (5.2.0)
# Requirement already satisfied: distro in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (1.9.0)
# Requirement already satisfied: tqdm>=4.32.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (4.66.5)
# Requirement already satisfied: python-gitlab in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (4.11.1)
# Requirement already satisfied: boto3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (1.35.26)
# Requirement already satisfied: keyrings.alt in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from datalad->nipype[all]) (5.0.2)
# Requirement already satisfied: jeepney>=0.4.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]) (0.8.0)
# Requirement already satisfied: jaraco.classes in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]) (3.4.0)
# Requirement already satisfied: jaraco.context in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]) (6.0.1)
# Requirement already satisfied: SecretStorage>=3.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]) (3.3.3)
# Requirement already satisfied: jaraco.functools in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from keyring!=23.9.0,>=20.0->datalad->nipype[all]) (4.0.2)
# Requirement already satisfied: cryptography>=2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from SecretStorage>=3.2->keyring!=23.9.0,>=20.0->datalad->nipype[all]) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring!=23.9.0,>=20.0->datalad->nipype[all]) (1.17.1)
# Requirement already satisfied: pycparser in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring!=23.9.0,>=20.0->datalad->nipype[all]) (2.22)
# Requirement already satisfied: botocore<1.36.0,>=1.35.26 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from boto3->datalad->nipype[all]) (1.35.26)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from boto3->datalad->nipype[all]) (0.10.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from boto3->datalad->nipype[all]) (1.0.1)
# Requirement already satisfied: h5py>=3.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from dipy->nipype[all]) (3.12.0)
# Requirement already satisfied: trx-python>=0.2.9 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from dipy->nipype[all]) (0.3)
# Requirement already satisfied: deepdiff in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from trx-python>=0.2.9->dipy->nipype[all]) (8.0.1)
# Requirement already satisfied: setuptools-scm in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from trx-python>=0.2.9->dipy->nipype[all]) (8.1.0)
# Requirement already satisfied: orderly-set==5.2.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from deepdiff->trx-python>=0.2.9->dipy->nipype[all]) (5.2.2)
# Requirement already satisfied: citeproc-py>=0.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from duecredit->nipype[all]) (0.6.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from GitPython->nipype[all]) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython->nipype[all]) (5.0.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (3.0.48)
# Requirement already satisfied: traitlets>=5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (5.14.3)
# Requirement already satisfied: exceptiongroup in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (1.2.2)
# Requirement already satisfied: stack-data in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (4.9.0)
# Requirement already satisfied: decorator in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from ipython->nipype[all]) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jedi>=0.16->ipython->nipype[all]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pexpect>4.3->ipython->nipype[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->nipype[all]) (0.2.13)
# Requirement already satisfied: more-itertools in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jaraco.classes->keyring!=23.9.0,>=20.0->datalad->nipype[all]) (10.5.0)
# Requirement already satisfied: backports.tarfile in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jaraco.context->keyring!=23.9.0,>=20.0->datalad->nipype[all]) (1.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jsonschema->bidsschematools>=0.10->bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (0.20.0)
# Requirement already satisfied: referencing>=0.28.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jsonschema->bidsschematools>=0.10->bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (0.35.1)
# Requirement already satisfied: attrs>=22.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jsonschema->bidsschematools>=0.10->bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jsonschema->bidsschematools>=0.10->bids-validator>=1.11->pybids>=0.7.0->nipype[all]) (2023.12.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib->nipype[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib->nipype[all]) (4.54.1)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib->nipype[all]) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib->nipype[all]) (6.4.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib->nipype[all]) (1.4.7)
# Requirement already satisfied: pillow>=8 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib->nipype[all]) (10.4.0)
# Requirement already satisfied: nbformat in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbsphinx->nipype[all]) (5.10.4)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbsphinx->nipype[all]) (7.16.4)
# Requirement already satisfied: jupyter-core>=4.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (5.7.2)
# Requirement already satisfied: defusedxml in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (1.5.1)
# Requirement already satisfied: beautifulsoup4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (4.12.3)
# Requirement already satisfied: jupyterlab-pygments in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (0.3.0)
# Requirement already satisfied: tinycss2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (1.3.0)
# Requirement already satisfied: bleach!=5.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (6.1.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (3.0.2)
# Requirement already satisfied: webencodings in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (0.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (8.6.3)
# Requirement already satisfied: pyzmq>=23.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (6.4.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nbformat->nbsphinx->nipype[all]) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx->nipype[all]) (2.6)
# Requirement already satisfied: joblib>=1.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nilearn->nipype[all]) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nilearn->nipype[all]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from scikit-learn>=1.0.0->nilearn->nipype[all]) (3.5.0)
# Requirement already satisfied: sympy>=1.9 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipy->nipype[all]) (1.13.3)
# Requirement already satisfied: transforms3d in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from nipy->nipype[all]) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sympy>=1.9->nipy->nipype[all]) (1.3.0)
# Requirement already satisfied: pynacl>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from paramiko->nipype[all]) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from paramiko->nipype[all]) (4.2.0)
# Requirement already satisfied: iniconfig in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pytest->nipype[all]) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pytest->nipype[all]) (1.5.0)
# Requirement already satisfied: setuptools>=30.3.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pytest-doctestplus->nipype[all]) (53.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from python-gitlab->datalad->nipype[all]) (1.0.0)
# Requirement already satisfied: pbr in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from sphinxcontrib-apidoc->nipype[all]) (6.1.0)
# Requirement already satisfied: executing>=1.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from stack-data->ipython->nipype[all]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from stack-data->ipython->nipype[all]) (2.4.1)
# Requirement already satisfied: pure-eval in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from stack-data->ipython->nipype[all]) (0.2.3)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.2 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: pytz>=2020.1 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/mnt/new_jxvs2_02/AshleyWorkspace/myenv/bin/python3 -m pip install --upgrade pip' command.

# %%
#function MARSS_getMPs:  used directly in MARSS
import os
import numpy as np
import nibabel as nib
import shutil
import nipype.interfaces.spm as spm
from nipype.interfaces import fsl
#import nipype as spm #does this work instead of above

def MARSS_getMPs(fn, MB, workingDir):
    # Load volume timeseries
    V = nib.load(fn)

    if V.shape[2] % MB != 0:
        raise ValueError(f"Number of slices and MB factor are incompatible for {fn}.")

    p, f = os.path.split(fn)
    f = os.path.splitext(f)[0]

    # Check workingDir for MPs
    mp_path = os.path.join(workingDir, f'rp_{f}.par')
    if not os.path.exists(mp_path):
        
        mcflt = fsl.MCFLIRT()
        
        mcflt.inputs.in_file = fn
        
        mcflt.inputs.cost = 'mutualinfo'
        
        rp_path = os.path.join(workingDir, "rp_" + f + ".nii" )
        mcflt.inputs.out_file = rp_path
        mcflt.inputs.output_type = "NIFTI"

        mcflt.inputs.save_rms = True
        mcflt.inputs.save_plots = True
        # mcflt.inputs.args = "-verbose -1"
        res = mcflt.run()

    # Copy the MP text file to the working directory
    if not os.path.exists(mp_path):
        # mp_file_src = os.path.join(p, f'rp_{f}.nii.par')
        # mp_file_dst = os.path.join(workingDir, f'rp_{f}.par')
        # mp_file_src = os.path.join(p, f'rp_{f}.par')
        
        # mp_file_src = os.path.join(workingDir, f'rp_{f}.nii.par')
        # mp_file_dst = os.path.join(workingDir, f'rp_{f}.txt')
        mp_file_src = os.path.join(workingDir, f'rp_{f}.txt')
        mp_file_dst = os.path.join(workingDir, f'rp_{f}.txt')        
        shutil.copyfile(mp_file_src, mp_file_dst)

    return mp_path

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio
from scipy.ndimage import rotate
import nibabel as nib

def zToR(z):
    return np.arctanh(z)

def MARSS(timeseriesFile, MB, workingDir):
    # Get name of run
    runName = os.path.splitext(os.path.basename(timeseriesFile))[0]

    # Create a new folder
    runDir = os.path.join(workingDir, runName)
    if not os.path.exists(runDir):
        os.makedirs(runDir)

    # Empty dictionary for all data to go to
    runStruct = {}

    print('Generating pre-MARSS Motion Parameters...')
    # Generate motion parameters for that run and save them
    preMARSS_MPpath = MARSS_getMPs(timeseriesFile, MB, runDir)
    
    # Load motion parameter file and save in DataFrame
    motionParams = pd.read_csv(preMARSS_MPpath)
    runStruct['preMARSS_motionParams'] = motionParams

    print('Generating pre-MARSS Slice Correlations...')
    # Generate slice correlation matrix and save in DataFrame
    preMARSS_corrs = MARSS_mbCorrPlot(timeseriesFile, motionParams, MB)
    preMARSS_sliceCorrelations = {
        'Z_avgSimulSliceCorr_motionRegressed': preMARSS_corrs['rdasimulSlicesZ'],
        'Z_avgAdjacentSliceCorr_motionRegressed': preMARSS_corrs['rdaAdjacentSlicesZ'],
        'R_avgSliceCorrDifference': zToR(preMARSS_corrs['rdasimulSlicesZ'] - preMARSS_corrs['rdaAdjacentSlicesZ']),
        'corrMat_motionRegressed': preMARSS_corrs['corrMat_motionRegressed']
    }
    runStruct['preMARSS_sliceCorrelations'] = pd.DataFrame(preMARSS_sliceCorrelations)
    
    print('Performing MARSS Procedure...')
    # Estimate and remove artifact function
    postMARSS_fname, postMARSS_avgSlcArt_fname = MARSS_removeSliceArtifact(timeseriesFile, MB, motionParams, runDir)
    
    print('Generating post-MARSS Motion Parameters...')
    # Use function to generate motion parameters for new artifact-removed data
    postMARSS_MPpath = MARSS_getMPs(postMARSS_fname, MB, runDir)
    
    # Load new motion parameters and save in DataFrame
    postmotionParams = pd.read_csv(postMARSS_MPpath)
    runStruct['postMARSS_motionParams'] = postmotionParams
    
    print('Generating post-MARSS Slice Correlations...')
    # Generate slice correlation matrix for artifact-removed run and save in DataFrame
    postMARSS_corrs = MARSS_mbCorrPlot(postMARSS_fname, postmotionParams, MB)
    postMARSS_sliceCorrelations = {
        'Z_avgSimulSliceCorr_motionRegressed': postMARSS_corrs['rdasimulSlicesZ'],
        'Z_avgAdjacentSliceCorr_motionRegressed': postMARSS_corrs['rdaAdjacentSlicesZ'],
        'R_avgSliceCorrDifference': zToR(postMARSS_corrs['rdasimulSlicesZ'] - postMARSS_corrs['rdaAdjacentSlicesZ']),
        'corrMat_motionRegressed': postMARSS_corrs['corrMat_motionRegressed']
    }
    runStruct['postMARSS_sliceCorrelations'] = pd.DataFrame(postMARSS_sliceCorrelations)

    # Save final struct 
    sio.savemat(os.path.join(runDir, runName + '_MARSS_SliceCorrelations.mat'), {'runStruct': runStruct})

    # Load avg artifact distribution
    artDistImg = nib.load(postMARSS_avgSlcArt_fname)
    artDistDat = artDistImg.get_fdata()
    maxArt = np.max(artDistDat)
    stdDat = np.std(artDistDat)
    meanArt = np.mean(artDistDat)
    # Color limit for displaying artifact distribution (mean + 3*stddev to control for outlier values)
    colorMax = meanArt + (3 * stdDat)

    # Generate multipanel summary figure
    fig, axs = plt.subplots(2, 6, figsize=(20, 10))

    # Pre-MARSS slice correlation matrix
    axs[0, 0].imshow(runStruct['preMARSS_sliceCorrelations']['corrMat_motionRegressed'], cmap='bwr', vmin=-1, vmax=1)
    axs[0, 0].set_title('Uncorrected Data')
    axs[0, 0].set_xlabel('Slice #')
    axs[0, 0].set_ylabel('Slice #')
    axs[0, 0].axis('equal')
    axs[0, 0].set_xticks([])
    axs[0, 0].set_yticks([])

    # Post-MARSS slice correlation matrix
    axs[0, 1].imshow(runStruct['postMARSS_sliceCorrelations']['corrMat_motionRegressed'], cmap='bwr', vmin=-1, vmax=1)
    axs[0, 1].set_title('Corrected Data')
    axs[0, 1].set_xlabel('Slice #')
    axs[0, 1].set_ylabel('Slice #')
    axs[0, 1].axis('equal')
    axs[0, 1].set_xticks([])
    axs[0, 1].set_yticks([])

    # Orthviews of artifact distribution
    axs[0, 2].imshow(rotate(artDistDat[:, :, artDistDat.shape[2]//2], -90), cmap='hot', vmin=0, vmax=colorMax)
    axs[0, 2].axis('off')

    axs[1, 0].imshow(rotate(artDistDat[:, artDistDat.shape[1]//2, :], 180), cmap='hot', vmin=0, vmax=colorMax)
    axs[1, 0].axis('off')

    axs[1, 1].imshow(rotate(artDistDat[artDistDat.shape[0]//2, :, :], 180), cmap='hot', vmin=0, vmax=colorMax)
    axs[1, 1].axis('off')

    plt.subplots_adjust(wspace=0, hspace=0.2)
    plt.savefig(os.path.join(runDir, 'MARSS_' + runName + '.png'))
    plt.close(fig)

    print('Completed MARSS for ' + runName + '.')

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio
from scipy.ndimage import rotate
import nibabel as nib

def MARSS_main(timeseriesFile, MB, workingDir):
    # Get name of run
    runName = os.path.splitext(os.path.basename(timeseriesFile))[0]

    # Create a new folder
    runDir = os.path.join(workingDir, runName)
    if not os.path.exists(runDir):
        os.makedirs(runDir)

    # Empty dictionary for all data to go to
    runStruct = {}

    print('Generating pre-MARSS Motion Parameters and Slice Correlations...')
    # Generate motion parameters for that run and save them
    
    preMARSS_MPpath = MARSS_getMPs(timeseriesFile, MB, runDir)
    matrix = text_to_matrix(preMARSS_MPpath)
    MARSS_mbCorrPlot(timeseriesFile, matrix, MB)  
    
    print('Performing MARSS Procedure...')
    [postMARSS_fname, postMARSS_avgSlcArt_fname] = MARSS_removeSliceArtifact(timeseriesFile, 6, matrix, runDir)
    
    print('Generating post-MARSS Motion Parameters and Slice Correlations...')
    postMARSS_MPpath = MARSS_getMPs(postMARSS_fname, MB, runDir)
    matrix = text_to_matrix(preMARSS_MPpath)
    MARSS_mbCorrPlot(postMARSS_fname, matrix, MB)

# %%
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/rp_50017_fMRI_Resting_1_AP.nii.par'
# ileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.par'
MARSS(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
# Out:
# Generating pre-MARSS Motion Parameters...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[142], line 2
#       1 # FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/rp_50017_fMRI_Resting_1_AP.nii.par'
# ----> 2 MARSS(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
#
# Cell In[130], line 29, in MARSS(timeseriesFile, MB, workingDir)
#      26 preMARSS_MPpath = MARSS_getMPs(timeseriesFile, MB, runDir)
#      28 # Load motion parameter file and save in DataFrame
# ---> 29 motionParams = pd.read_csv(preMARSS_MPpath)
#      30 runStruct['preMARSS_motionParams'] = motionParams
#      32 print('Generating pre-MARSS Slice Correlations...')
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.par'

# %%
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/rp_2875_3T_RS_fMRI_1.nii.par'
MARSS(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/")

# %%
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.par'
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.par'
MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
# Out:
# Generating pre-MARSS Motion Parameters and Slice Correlations...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[143], line 2
#       1 # FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.par'
# ----> 2 MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
#
# Cell In[139], line 25, in MARSS_main(timeseriesFile, MB, workingDir)
#      22 # Generate motion parameters for that run and save them
#      24 preMARSS_MPpath = MARSS_getMPs(timeseriesFile, MB, runDir)
# ---> 25 matrix = text_to_matrix(preMARSS_MPpath)
#      26 MARSS_mbCorrPlot(timeseriesFile, matrix, MB)
#      28 print('Performing MARSS Procedure...')
#
# Cell In[114], line 6, in text_to_matrix(file_path)
#       3 def text_to_matrix(file_path):
#       4     """Converts a text file to a numpy matrix."""
# ----> 6     with open(file_path, 'r') as f:
#       7         lines = f.readlines()
#       9     matrix = []
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.par'

# %%
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/rp_2875_3T_RS_fMRI_1.txt'
MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/")

# %%
MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_MATLAB")
# Out:
# Generating pre-MARSS Motion Parameters...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 MARSS_main(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_MATLAB")
#
# Cell In[76], line 23, in MARSS_main(timeseriesFile, MB, workingDir)
#      21 print('Generating pre-MARSS Motion Parameters...')
#      22 # Generate motion parameters for that run and save them
# ---> 23 preMARSS_MPpath = MARSS_getMPs(timeseriesFile, MB, runDir)
#      24 print(preMARSS_MPpath)
#
# Cell In[119], line 45, in MARSS_getMPs(fn, MB, workingDir)
#      43     mp_file_src = os.path.join(p, f'rp_{f}.txt')
#      44     mp_file_dst = os.path.join(workingDir, f'rp_{f}.txt')
# ---> 45     shutil.copyfile(mp_file_src, mp_file_dst)
#      47 return mp_path
#
# File /usr/lib64/python3.9/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
#     267                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/new_jxvs2_02/AshleyWorkspace/rp_2875_3T_RS_fMRI_1.txt'

# %%
import numpy as np

def text_to_matrix(file_path):
    """Converts a text file to a numpy matrix."""

    with open(file_path, 'r') as f:
        lines = f.readlines()

    matrix = []
    for line in lines:
        row = [float(x) for x in line.split()]  # Adjust split() if delimiter is different
        matrix.append(row)

    return np.array(matrix)

matrix = text_to_matrix('/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/50017_fMRI_Resting_1_AP/rp_50017_fMRI_Resting_1_AP.nii.par')
print(matrix)
# Out:
# [[ 1.99335e-03  4.00333e-05  2.34281e-04  5.28906e-02 -3.89199e-02
#    2.47240e-01]
#  [ 1.89470e-03 -9.22408e-05  2.26994e-04  5.35598e-02 -1.35466e-02
#    2.15855e-01]
#  [ 1.24729e-03  8.81252e-05  5.03600e-05  4.76625e-02  9.04525e-02
#    2.57395e-01]
#  ...
#  [ 7.33110e-03  2.06875e-03  7.33981e-05  6.52053e-02  1.05198e-01
#    5.62158e-01]
#  [ 6.80244e-03  2.27931e-03 -5.76533e-05  7.15141e-02  1.49518e-01
#    6.53931e-01]
#  [ 7.39474e-03  2.72833e-03 -2.27835e-04  8.25707e-02 -4.51549e-02
#    3.93574e-01]]

# %%
import numpy as np
import nibabel as nib
timeSeriesDat = nib.load(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii");
timeSeriesDat = timeSeriesDat.get_fdata()
# d = squeeze(mean(mean(nY,1),2))';
d = np.mean(np.mean(timeSeriesDat, axis = 0), axis = 0)
d = d.T
print(d)
# cell not necessary
# Out:
# [[37.56012029 38.91942682 39.37958464 ... 19.05920306 18.38370419
#   16.99806915]
#  [38.0932823  39.1112549  39.88057604 ... 19.14664681 18.38703685
#   16.97388814]
#  [38.08198228 38.98756123 39.79586873 ... 19.18075177 18.44186586
#   16.99824881]
#  ...
#  [38.19948129 38.57010474 39.81457259 ... 19.92347136 18.95482031
#   17.70490185]
#  [37.91249726 38.49905736 40.04904464 ... 19.90696642 18.95795905
#   17.70448957]
#  [37.79848012 38.80063529 39.98819201 ... 19.88295245 18.94256701
#   17.66035919]]

# %%
# MARSS_mbCorrPlot.m
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import nibabel as nib

def MARSS_mbCorrPlot(fname,MPs,MB,runDir):

    timeSeriesDat = nib.load(fname);
    timeSeriesDat = timeSeriesDat.get_fdata()
    # d = squeeze(mean(mean(nY,1),2))';
    d = np.mean(np.mean(timeSeriesDat, axis = 0), axis = 0)
    d = d.T    

    # % nuisance regressor design matrix [intercept, linearDetrend, MPs,squared
    # % MPs, derivatives of MPs, squared derivatives]
    # X = [ones(size(d,1),1) (1:size(d,1))' MPs MPs.^2 [zeros(1,6); diff(MPs)] [zeros(1,6); diff(MPs)].^2];
    intercept = (np.ones((int(d.shape[0]),1)))
    linearDetrend = (np.arange(1, (int(d.shape[0]))+1))
    linearDetrend = linearDetrend[:,np.newaxis]
    MPs_derivatives = np.vstack(((np.zeros(6), np.diff(matrix,axis = 0))))
    squared_MPs_derivatives =  np.vstack((np.zeros(6), np.diff(matrix,axis = 0)))**2 #cannot assign to function call
    X = np.hstack((intercept, linearDetrend,  matrix, matrix**2, MPs_derivatives, squared_MPs_derivatives))
    
    # rd = zeros(size(d));
    rd = np.zeros(d.shape)
    
    # for i = 1:size(d,2)
    #     rd(:,i) = d(:,i) - (X*(X\d(:,i)));
    # end
    for i in range(d.shape[1]):
        # Solve the least-squares problem X \ d[:,i] -> in Python it's np.linalg.lstsq
        beta = np.linalg.lstsq(X, d[:, i], rcond=None)[0]
        
        # Calculate the residual: d[:, i] - X @ beta
        rd[:, i] = d[:, i] - X @ beta
    
    # print(rd)

    #todo
    # add in MARSS_avgMBcorr(rd,MB)
    # needs to output avgS_Z and avgNS_Z
    # correlation difference = z-to-R transform of (avgS_Z - avgNS_Z) formula in slack

    [avgS_Z, avgNS_Z] = MARSS_avgMBcorr(rd,MB)
    # r = (exp(2.*Z) - 1) ./ (exp(2.*Z) + 1);
        # cZ = 0.5 * np.log((1 + c) / (1 - c))
    Z = (avgS_Z - avgNS_Z)
    correlation_difference = (np.exp(2 * Z) - 1) / (np.exp(2 * Z) + 1)


    
    # out.corrMat_motionRegressed = corr(rd);
    corr = np.corrcoef(rd, rowvar=False) 
    
    # Create the heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr, annot=False, cmap='viridis')
    #todo MAKE THE TITLE THE CORRELATION DIFFERENCE ("Delta_R = " + correlation difference) of a png heatmap
    plt.title("Δ_R = " + correlation_difference)
    plt.show()

    plt.savefig(os.path.join(runDir, 'Δ_R = ' + correlation_difference + '.png'))
    # save correlation matrix as png to runDir (will require some filename manipulations)

# %%
import os
import pandas as pd

os.getcwd()
print(corr)
# np.savetxt("foo.csv", corr, delimiter=",")
my_df = pd.DataFrame(corr)
my_df.to_csv('/mnt/new_jxvs2_02/AshleyWorkspace/foo.csv', index=False)

# %%
import csv
# MARSS_avgMBcorr.m
def MARSS_avgMBcorr(dat, MB):
    c = np.corrcoef(dat, rowvar=False)
    cZ = 0.5 * np.log((1 + c) / (1 - c))
    sgap = c.shape[0] / MB

    # [avgS_Z, avgNS_Z] = deal(zeros(size(c, 1), 1));
    num_rows = c.shape[0]  
    avgS_Z = np.zeros((num_rows, 1))
    avgNS_Z = np.zeros((num_rows, 1))

    # empty array to append ind to 
    rows = []

    for i in range(c.shape[0]):
        cntS = 0;
        cntNS = 0; #where is this used?
        # from i-sgap to 1 in increments of -sgap
        # ind = [(i-sgap):-sgap:1 (i+sgap):sgap:size(c,1)];
        # ind = np.concatenate((np.arange(i - sgap, 0, -sgap), np.arange(i + sgap, num_rows+1, sgap)))
        ind = np.concatenate((np.arange(i - sgap, -1, -sgap), np.arange(i + sgap, num_rows, sgap)))     
        ind = np.array(ind, dtype=int)
        
        # # avgS_Z(i) = mean(cZ(i,ind));
        # avgS_Z[i] = np.mean(cZ[i, ind-1])
        avgS_Z[i] = np.mean(cZ[i, ind])
        
        #adjacent slices
        # ind = [ind-1 ind+1];
        # ind(ind<1|ind>size(c,1)) = [];
        # avgNS_Z(i) = mean(cZ(i,ind));
        ind = np.concatenate((ind - 1, ind + 1))  # Create adjacent indices
        ind = ind[(ind >= 0) & (ind < num_rows)]  # Keep only valid indices
        # WARNING: THESE CORRELATIONS ARE VERY DIFFERENT THAN THE MATLAB VERSION OF MARSS AS OF NOW
        avgNS_Z[i] = np.mean(cZ[i, ind-1])  # Adjust index for zero-based indexing
    print(np.mean(avgS_Z - avgNS_Z))
    
MARSS_avgMBcorr(rd,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 49
#      37     print(np.mean(avgS_Z - avgNS_Z))
#      39     # simulSlicesZ = np.mean(avgS_Z)
#      40     # adjacentSlicesZ = np.mean(avgNS_Z)
#      41
#    (...)
#      46  #       writer = csv.writer(file)
#      47  #       writer.writerows(rows)
# ---> 49 MARSS_avgMBcorr(rd,6)
#
# NameError: name 'rd' is not defined

# %%
# MARSS_estimateSliceArtifact used in MARSS_removeSliceArtifact
from scipy.stats import zscore

def MARSS_estimateSliceArtifact(Y,MB,X):

    # if mod(size(Y,3),MB)
    #     error('# of slices and MB factor are incompatible.');
    # end
    if Y.shape[2] % MB != 0:
        raise ValueError("# of slices and MB factor are incompatible.")
    
    # nSlices = size(Y,3);
    # nSliceSets = nSlices/MB;
    # data = squeeze(mean(mean(Y,1),2))';
    nSlices = Y.shape[2]
    nSliceSets = nSlices // MB
    data = np.squeeze(np.mean(np.mean(Y, axis=1), axis=0)).T
    # print(nSlices, nSliceSets, data)

    # X = zscore(X);
    # X = zscore(X, axis=0, ddof=1) 
    X = zscore(X, axis=0, ddof=1) 
    #print(X)

    # [sameSetData,artifactEstimate,globalSignal] = deal(zeros(size(data)));
    sameSetData = np.zeros_like(data)
    artifactEstimate = np.zeros_like(data)
    globalSignal = np.zeros_like(data)

    for j in range(nSlices):
        sliceSet = j % nSliceSets
        #if sliceSet == 0:
        #    sliceSet = nSliceSets
        
        sameSliceSet = np.zeros(nSlices, dtype=bool)  # Initialize boolean array for same slice set
        lowerSlices = np.arange(sliceSet, j, nSliceSets)  # Get lower slices
        higherSlices = np.arange(j + nSliceSets, nSlices, nSliceSets)  # Get higher slices
        sameSliceSet[np.concatenate((lowerSlices, higherSlices))] = True  # Set slices in the same slice set
        # print(sameSliceSet)
    
        # Calculate sameSetData for the current slice j
        sameSetData[:, j] = np.mean(data[:, sameSliceSet], axis=1)
    
        # Exclude current slice from global signal calculation
        sameSliceSet[j] = True
        #res = [idx for idx, val in enumerate(sameSliceSet) if val]
        #print(res)
        globalSignal[:, j] = np.mean(data[:, ~sameSliceSet], axis=1)
    
        # Design matrix: [intercept, globalSignal, MPs (X)]
        Xout = np.column_stack((np.ones(data.shape[0]), zscore(globalSignal[:, j],ddof = 1), X))
    
        # Perform the regression (solve the system of equations)
        B = np.linalg.lstsq(Xout, sameSetData[:, j], rcond=None)[0]
    
        # Compute artifact estimate
        artifactEstimate[:, j] = sameSetData[:, j] - Xout @ B
    return [artifactEstimate, globalSignal]

# %%
Xest = np.hstack((matrix, matrix**2, MPs_derivatives, squared_MPs_derivatives))
# save artifactEstimate as csv
[artifactEstimate, nonsliceGlobalSignal] = MARSS_estimateSliceArtifact(timeSeriesDat,6,Xest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 Xest = np.hstack((matrix, matrix**2, MPs_derivatives, squared_MPs_derivatives))
#       2 [artifactEstimate, nonsliceGlobalSignal] = MARSS_estimateSliceArtifact(timeSeriesDat,6,Xest)
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/numpy/_core/shape_base.py:358, in hstack(tup, dtype, casting)
#     356     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     357 else:
# --> 358     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 532 and the array at index 2 has size 563

# %%
# Xest = [MPs MPs.^2 [zeros(1,6); diff(MPs)] [zeros(1,6); diff(MPs)].^2];
Xest = np.hstack((matrix, matrix**2, MPs_derivatives, squared_MPs_derivatives))

MARSS_estimateSliceArtifact(timeSeriesDat,6,Xest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 2
#       1 # Xest = [MPs MPs.^2 [zeros(1,6); diff(MPs)] [zeros(1,6); diff(MPs)].^2];
# ----> 2 Xest = np.hstack((matrix, matrix**2, MPs_derivatives, squared_MPs_derivatives))
#       4 MARSS_estimateSliceArtifact(timeSeriesDat,6,Xest)
#
# File /mnt/new_jxvs2_02/AshleyWorkspace/myenv/lib64/python3.9/site-packages/numpy/_core/shape_base.py:358, in hstack(tup, dtype, casting)
#     356     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     357 else:
# --> 358     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 532 and the array at index 2 has size 563

# %%
import numpy as np
import nibabel as nib
import os
import pandas as pd

# MARSS_removeSliceArtifact.m
def MARSS_removeSliceArtifact(filename,MB,MPs,working_dir):
    # V = spm_vol(filename{i});
    # Y = spm_read_vols(V);
    # for j = 1:length(V)
    #     V(j).dt = [16 0];
    # end
    # Y = double(Y);         
    img = nib.load(filename)
    Y = img.get_fdata()
    V = img.header

    # print(img.shape)
    # print(img.affine)
    # print(V.affine)
    
    # Modify the header data type (equivalent to V(j).dt = [16 0])
    # In Nibabel, you modify the datatype using the header object
    hdr = img.header
    hdr.set_data_dtype(np.float32)  # Equivalent to SPM's [16 0] (single precision float)
    # Convert the data to double precision (equivalent to Y = double(Y))
    Y = Y.astype(np.float64)

    # if mod(size(Y,3),MB)
    #     warning(['# of slices and MB factor are incompatible for ' filename{i} '. Skipping.']);
    #     continue
    # end    
    if Y.shape[2] % MB != 0:
        print(f"Warning: # of slices and MB factor are incompatible for {filename}. Skipping.")
        

    MPs = (MPs - np.mean(MPs)) / np.std(MPs)  # Z-score normalization
    # Nuisance parameter design matrix
    Xest = np.hstack([
            MPs,
            MPs ** 2,
            np.vstack([np.zeros((1, 6)), np.diff(MPs, axis=0)]),
            np.vstack([np.zeros((1, 6)), np.diff(MPs, axis=0)]) ** 2
    ])
    
    # Estimate artifact signal in each slice
    [artifactEstimate, nonsliceGlobalSignal] = MARSS_estimateSliceArtifact(Y, MB, Xest) 


    Ya = np.zeros_like(Y)
    Yart = np.zeros_like(Y)   
    for j in range(artifactEstimate.shape[1]):
        # Final MARSS design matrix
        Xcalc = np.column_stack([np.ones(artifactEstimate.shape[0]), (artifactEstimate[:, j] - np.mean(artifactEstimate[:, j])) / np.std(artifactEstimate[:, j]), 
                                 (nonsliceGlobalSignal[:, j] - np.mean(nonsliceGlobalSignal[:, j])) / np.std(nonsliceGlobalSignal[:, j]),
                                 (Xest - np.mean(Xest, axis=0)) / np.std(Xest, axis=0)])

        Yt = Y[:, :, j, :].reshape(-1, Y.shape[3]).T
        # Perform regression
        B = np.linalg.lstsq(Xcalc, Yt, rcond=None)[0]

        # print(Xcalc.shape)
        # print(B.shape)

        # art = Xcalc[:, 1] @ B[1, :]
        # art = np.dot(Xcalc[:,1], B[1,:])
        art = np.outer(Xcalc[:, 1], B[1, :])
        # Subtract artifact estimation from original timeseries data
        # Yta = (Yt.T - art.T).T.reshape(Y.shape[0], Y.shape[1], 1, Y.shape[3])
        # Yartt = art.reshape(Y.shape[0], Y.shape[1], 1, Y.shape[3])
        Y_diff = Yt.T - art.T
        Yta = np.reshape(Y_diff, (Y.shape[0], Y.shape[1], Y.shape[3]))

        Yartt = np.reshape(art.T, (Y.shape[0], Y.shape[1], Y.shape[3]))
        Ya[:, :, j, :] = Yta
        Yart[:, :, j, :] = Yartt

        # Create filenames for output
        base_name = os.path.basename(filename)
        f, x = os.path.splitext(base_name)

    
    for j in range(Y.shape[3]):
        # Corrected Data
        corrected_filename = os.path.join(working_dir, f'za{f}{x}')
        #print(V)
        # nib.save(nib.Nifti1Image(Ya[:, :, :, j], img.affine), corrected_filename)
        

        # Isolated artifact timeseries
        artifact_filename = os.path.join(working_dir, f'{f}_slcart{x}')
        # nib.save(nib.Nifti1Image(Yart[:, :, :, j], img.affine), artifact_filename)
    
    nib.save(nib.Nifti1Image(Ya, img.affine), corrected_filename)
    nib.save(nib.Nifti1Image(Yart, img.affine), artifact_filename)
             
    Yaavg = np.mean(np.abs(Yart), axis=3)

    # Average artifact distribution
    avg_artifact_filename = os.path.join(working_dir, f'{f}_AVGslcart{x}')
    nib.save(nib.Nifti1Image(Yaavg, img.affine), avg_artifact_filename)

    postMARSS_fname = os.path.join(working_dir, f'za{f}{x}')
    postMARSS_avgSlcArt_fname = os.path.join(working_dir, f'{f}_AVGslcart{x}')    
        
    return [postMARSS_fname, postMARSS_avgSlcArt_fname]

# %%
import numpy as np

def text_to_matrix(file_path):
    """Converts a text file to a numpy matrix."""

    with open(file_path, 'r') as f:
        lines = f.readlines()

    matrix = []
    for line in lines:
        row = [float(x) for x in line.split()]  # Adjust split() if delimiter is different
        matrix.append(row)

    return np.array(matrix)

matrix = text_to_matrix('/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/2875_3T_RS_fMRI_1/rp_2875_3T_RS_fMRI_1.nii.par')
# print(matrix)

# print(MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/"))
# MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
[postMARSS_fname, postMARSS_avgSlcArt_fname] = MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/")
# MARSS_avgMBcorr(postMARSS_fname,6)
MARSS_mbCorrPlot(postMARSS_fname, matrix, 6)
# Out:
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
#            0         1         2         3         4         5         6   \
# 0   -0.321242  0.350193 -0.154467  0.159157 -0.184125  0.086773 -0.073629
# 1    0.293660  0.435050 -0.255954  0.243992 -0.120193 -0.112064 -0.064820
# 2   -0.067827  0.345334 -0.217857  0.252604 -0.177248 -0.090226  0.000543
# 3   -0.449994 -0.025980 -0.088877  0.527749 -0.161020  0.242551 -0.000057
# 4    0.245429  0.117624  0.035683 -0.250115 -0.105072  0.093209 -0.184629
# ..        ...       ...       ...       ...       ...       ...       ...
# 527  0.179827  0.045050  0.181578  0.018319 -0.031500 -0.428639  0.015039
# 528 -0.141176  0.183774 -0.219644  0.067020  0.081803  0.057647 -0.207592
# 529 -0.341783  0.071706  0.044788  0.218442 -0.159438  0.409094 -0.076079
# 530 -0.023519 -0.159928  0.101777  0.122535  0.121038  0.260393 -0.245076
# 531  0.172332 -0.029055  0.059517 -0.044789  0.123501 -0.062811 -0.033777
#
#            7         8         9   ...        56        57        58  \
# 0    0.188681  0.080194  0.035856  ...  0.313883 -0.238566  0.210783
# 1   -0.032988  0.101796 -0.190795  ...  0.419238 -0.196422  0.257607
# 2    0.090628  0.188937  0.145721  ...  0.309529 -0.246757  0.258284
# 3    0.080989 -0.000546  0.167280  ... -0.029105 -0.150107  0.502891
# 4    0.288887 -0.291987  0.003780  ...  0.058348  0.039001 -0.222700
# ..        ...       ...       ...  ...       ...       ...       ...
# 527 -0.236000 -0.081791 -0.403339  ...  0.177936  0.211481  0.100290
# 528  0.005663  0.287845 -0.054125  ...  0.221256 -0.173172  0.132723
# 529  0.078114  0.097708  0.110235  ...  0.021710 -0.063830  0.188146
# 530 -0.089786 -0.037709  0.265559  ... -0.200915  0.071075  0.083859
# 531 -0.219771  0.187093  0.180104  ... -0.138045  0.021977 -0.112462
#
#            59        60        61        62        63        64        65
# 0   -0.198324  0.141160 -0.068851  0.232356  0.111090  0.195184  0.111279
# 1    0.002691 -0.096162  0.011708 -0.062823  0.118192 -0.218946 -0.333591
# 2   -0.165580 -0.036536 -0.014506  0.108668  0.213092  0.109840 -0.260875
# 3   -0.169992  0.263869  0.009310  0.069582 -0.015834  0.121860 -0.030031
# 4   -0.195995  0.107310 -0.213356  0.337011 -0.231814  0.085607 -0.068568
# ..        ...       ...       ...       ...       ...       ...       ...
# 527  0.023536 -0.444445  0.048835 -0.235839 -0.060570 -0.322939  0.263935
# 528  0.128242  0.087440 -0.163931 -0.002152  0.319164 -0.061840 -0.085407
# 529 -0.244179  0.418171 -0.080744  0.040955  0.059584  0.066022 -0.191435
# 530  0.121763  0.237902 -0.282413 -0.098672 -0.081283  0.283898 -0.121677
# 531  0.099000 -0.088826 -0.079755 -0.222599  0.180092  0.191651 -0.011975
#
# [532 rows x 66 columns]
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# ...
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  4  96  96  66 532   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.   2.   2.   2.   0.85 1.   1.   1.  ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 1000.0
# cal_min         : 1.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'2203.6-dirty 2022-09-08T15:38:56+01:00')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.038728833
# quatern_c       : 0.013593769
# quatern_d       : -0.01310818
# qoffset_x       : -98.68299
# qoffset_y       : -92.55331
# qoffset_z       : -59.144077
# srow_x          : [ 1.9985737e+00  5.4484043e-02  5.2294143e-02 -9.8682442e+01]
# srow_y          : [-5.0272387e-02  1.9933132e+00 -1.5548444e-01 -9.2553871e+01]
# srow_z          : [-5.6355011e-02  1.5405852e-01  1.9932612e+00 -5.9144081e+01]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')

# %%
# MARSS_avgMBcorr(rd,6)
MARSS_avgMBcorr(postMARSS_fname,6)
# Out:
# here

# %%
# MARSS(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
# [postMARSS_fname, postMARSS_avgSlcArt_fname] = MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_fMRI_1.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/2875_3T_RS_MARSS/")

[postMARSS_fname, postMARSS_avgSlcArt_fname] = MARSS_removeSliceArtifact(r"/mnt/new_jxvs2_02/AshleyWorkspace/50017_fMRI_Resting_1_AP.nii", 6, matrix, r"/mnt/new_jxvs2_02/AshleyWorkspace/50017MARSS/")
# Out:
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
# [0, 11, 22, 33, 44, 55]
# [1, 12, 23, 34, 45, 56]
# [2, 13, 24, 35, 46, 57]
# [3, 14, 25, 36, 47, 58]
# [4, 15, 26, 37, 48, 59]
# [5, 16, 27, 38, 49, 60]
# [6, 17, 28, 39, 50, 61]
# [7, 18, 29, 40, 51, 62]
# [8, 19, 30, 41, 52, 63]
# [9, 20, 31, 42, 53, 64]
# [10, 21, 32, 43, 54, 65]
#             0          1          2          3          4          5   \
# 0    -1.714946   2.137581  11.816138  30.472028   8.392331  -1.671213
# 1     6.541152   6.154475   1.978773  12.768394  15.325725   8.419557
# 2    -1.148113   5.374181  13.216843  -0.622512   0.790225   8.803155
# 3    -4.178241  22.582803  27.770960  19.964648   6.026086  10.719245
# 4    -8.460715   0.605924   5.701540   7.427958  15.873929  -1.074621
# ..         ...        ...        ...        ...        ...        ...
# 558  -0.339886  -2.564836  -7.944093 -17.961109 -15.971903   0.920130
# 559   8.157429   5.184298   9.010750   1.135964  -1.602523   6.809803
# 560   1.757184   4.388002 -16.153104  -9.175075  11.759146   6.377650
# 561  21.691826  20.062014  24.708804  14.465529  -8.559714  -9.919949
# 562   4.799644   1.823543  -0.252779   8.024257   9.561534   4.096758
#
#             6          7          8          9   ...         56         57  \
# 0    25.102455  15.728303  -3.737019 -17.369644  ...  -2.067418   4.847649
# 1     0.399637 -11.576851 -13.530938  -8.013701  ...   5.127762  -6.184574
# 2     4.119098  -8.297050 -14.706760  -9.052684  ...   7.172761  14.490151
# 3    -4.406372 -19.037088 -24.189082 -16.891063  ...  20.683204  27.550583
# 4     3.304235  10.135464  -0.083971  -6.689814  ...  -1.463199   3.251720
# ..         ...        ...        ...        ...  ...        ...        ...
# 558   1.148375   6.943003  16.927043  20.507393  ...  -7.445498 -10.151957
# 559   2.364339   2.362416  -2.068346   0.843390  ...  -2.991944   4.642143
# 560  -7.288201 -11.938956  12.209971  12.696502  ...   4.536856 -20.570544
# 561 -13.293076  -7.659345  -1.429833  -8.525733  ...  20.345559  26.671202
# 562  -2.968812   8.355053   8.766055  -5.653750  ...   2.205978   0.395731
#
#             58         59         60         61         62         63  \
# 0    24.507815   1.944720  -6.244796  21.435261  14.265176  -7.400613
# 1     2.114535   6.972665   6.446085  -4.068802 -14.980516 -15.449393
# 2    -7.437222  -6.784273   5.480557   6.228503  -8.199392 -16.430940
# 3    18.415868  -2.570529   7.982069  -4.267625 -18.772563 -24.774835
# 4     5.004366  11.957716 -10.142250  -1.502832   9.535483  -0.970266
# ..         ...        ...        ...        ...        ...        ...
# 558 -20.645033 -19.642458  -2.139533   0.004499   4.046600  14.011133
# 559  -2.036463  -3.502442   6.608804   3.153321   1.581941  -5.137869
# 560 -13.426376   8.072003   5.021817  -9.262363 -15.206743  10.588766
# 561  12.041227 -16.498761 -12.078617 -15.765330  -8.466252  -3.423066
# 562   8.343539   9.518832   0.589851  -5.182142   8.367769   9.571208
#
#             64         65
# 0   -22.218331 -11.932482
# 1    -8.968122  -8.416612
# 2    -9.692741  -2.309963
# 3   -17.731728 -16.439516
# 4    -9.237687 -16.332212
# ..         ...        ...
# 558  21.618614  16.626542
# 559   0.463739  -3.014340
# 560  12.854818  11.782398
# 561 -10.934737  -6.478484
# 562  -5.775762 -10.670726
#
# [563 rows x 66 columns]
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# ...
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'S2938_V23_JV')
# extents         : 16384
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 185
# dim             : [  4 102 102  66 563   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.   2.   2.   2.   0.8  0.   0.   0. ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 65
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 44897
# glmin           : 0
# descrip         : np.bytes_(b'phase=-y;readout=0.0596;dwell=0.59;TE=25;time=20171011111358.987;')
# aux_file        : np.bytes_(b'Unaliased MB6/PE3/LB;SIE')
# qform_code      : scanner
# sform_code      : aligned
# quatern_b       : -0.04996614
# quatern_c       : -0.99124205
# quatern_d       : -0.121965006
# qoffset_x       : 89.65338
# qoffset_y       : -82.23821
# qoffset_z       : -106.27095
# srow_x          : [-1.9897451e+00  2.0211101e-01  8.1067681e-03  8.9653381e+01]
# srow_y          : [  0.19411731   1.9305117   -0.48522472 -82.23821   ]
# srow_z          : [ 5.6859732e-02  4.8194993e-01  1.9402297e+00 -1.0627095e+02]
# intent_name     : np.bytes_(b'cmrr_mbep2d_bold')
# magic           : np.bytes_(b'n+1')
